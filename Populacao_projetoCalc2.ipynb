# %%
##PROJETO CÁLCULO II

from sympy import *

t, c = symbols ('t, c')
init_printing(use_unicode = True)

print("ESTIMA-SE QUE A t MESES A POPULAÇÃO DE UM CERTO VILAREJO ESTARÁ VARIANDO A UMA TAXA DE dp/dt = 2 + 6 * √t pessoas por mês.")
print("QUAL SERÁ A POPULAÇÃO DESTE VILAREJO EM 9 MESES SABENDO QUE A POPULAÇÃO ATUAL DO VILAREJO É DE 2000 PESSOAS?")
print()
print("ƒ(x) = 2 + 6 * √t")
# Out:
# ESTIMA-SE QUE A t MESES A POPULAÇÃO DE UM CERTO VILAREJO ESTARÁ VARIANDO A UMA TAXA DE dp/dt = 2 + 6 * √t pessoas por mês.
# QUAL SERÁ A POPULAÇÃO DESTE VILAREJO EM 9 MESES SABENDO QUE A POPULAÇÃO ATUAL DO VILAREJO É DE 2000 PESSOAS?
#
# ƒ(x) = 2 + 6 * √t

# %%
Integral(2 + 6 * sqrt(t)) # Monta a expressão de maneira desenhada
# Out:
# ⌠
# ⎮ (6⋅√t + 2) dt
# ⌡

# %%
Integral(2 + 6 * sqrt(t)).doit()  # Resolve a expressão criada anteriormente
# Out:
#    3/2
# 4⋅t    + 2⋅t

# %%
t = int(input())
c = int(input()) #constante populacao atual 2000 

populacao = (4*(t**(3/2))+2*t+c)

print("APÓS %d MESES" %t + " A POPULAÇÃO É DE %0.2f" %populacao)
# Out:
# 9
# 2000
# APÓS 9 MESES A POPULAÇÃO É DE 2126.00
