# %%
from sympy import* #biblioteca que calcula integrais
from math import sqrt #biblioteca que calcula raiz quadrada
# %matplotlib inline 
from sympy.plotting import* #biblioteca para a criacao dos grafico

t, c = symbols ('t c')
init_printing(use_unicode = True)

print("A ÁREA ESTÁ COMPREENDIDA ENTRE A FUNCAO ƒ(x) = (-x**2) + 4")
# Out:
# A ÁREA ESTÁ COMPREENDIDA ENTRE A FUNCAO ƒ(x) = (-x**2) + 4

# %%
x = Symbol('x')

plot((-x**2) + 4)

# %%
f = input() 
#a variavel f recebe a funcao que iremos calcular a integral definida que no nosso caso sera f(x) = (-x**2) + 4
#as variaveis abaixo (x1 e x2) definem o limite onde a integral sera calculada
x1 = int(input())
x2 = int(input())

#print("O RESULTADO É ")
#integrate(f, (x, x1, x2))
Integral(f, (x, x1, x2))
# Out:
# (-x**2) + 4
# 2
# -2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-797f8b63752a> in <module>
#       7 #print("O RESULTADO É ")
#       8 #integrate(f, (x, x1, x2))
# ----> 9 Integral(f, (x, x1, x2))
#
# NameError: name 'Integral' is not defined
